# %%
import numpy as np
import torch
import glob
import matplotlib.pyplot as plt
import hydra
import os
from datetime import datetime
import json

# %%
temp = {i[29:-4]:i for i in glob.glob('../src/models/trained_models/*.pth')}

# %%
acc = {"trained_model_05-01-22:2154": 10.040000081062317, "trained_model_05-01-22:2207": 10.599999874830246, "trained_model_05-01-22:2213": 12.120000272989273, "trained_model_05-01-22:2218": 9.239999949932098}

# %%
max(acc,key=acc.get)
# Out:
# 'trained_model_05-01-22:2213'

# %%
for item in temp:
    if item not in acc.keys():
        acc[item] = 5

# %%
acc
# Out:
# {'trained_model_best': 5}

# %%
temp = np.load("../data/raw/test.npz")

# %%
for i in range(10):
    plt.imshow(temp['images'][i])
    plt.show()
